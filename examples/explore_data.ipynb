# %% [markdown]
# # Explore the data

# %% [markdown]
# ## Import Dependencies

# %%
import sys
import os
import numpy as np

# %% [markdown]
# ### Add utils to sys to import our custom scripts

# %% [markdown]
# **Note:** This notebook should be run from the `examples` folder to ensure the correct imports and file paths are used.

# %%
# Go up one level from 'examples' and point to 'utils' folder
utils_path = os.path.abspath(os.path.join(os.getcwd(), os.pardir, 'utils'))
# Add the 'utils' folder to sys.path
sys.path.append(utils_path)
import data_utils

# %% [markdown]
# ## Data exploration

# %% [markdown]
# ### Load examples from the /data folder

# %%
example_data = {"VT": "../data/example_VT.npy",
                 "LP": "../data/example_LP.npy",
                 "TR": "../data/example_TR.npy",
                 "AV": "../data/example_AV.npy",
                 "IC": "../data/example_IC.npy",
                 }

# %% [markdown]
# ### Plot the trace (8 channels) with its corresponding -true- segmentation
# Notice that the "BG" class indicates the presence of an event (when 0) or not (when 1). Only the corresponding class of the event is activated (value of 1) when the event is present, and turns back to 0 when it is no longer there.

# %% [markdown]
# Volcano-Tectonic (VT) example:

# %%
example_trace = np.load(example_data['VT'])
data_utils.plot_trace(example_trace,
                        n_stations=8,
                        save_path=None,
                        save=False,
                        title="",
                        num=0,
                        dpi=100,
                        figsize=(10, 6),
                        font_size=9)

# %% [markdown]
# Long-Period (LP) example:

# %%
example_trace = np.load(example_data['LP'])
data_utils.plot_trace(example_trace,
                        n_stations=8,
                        save_path=None,
                        save=False,
                        title="",
                        num=0,
                        dpi=100,
                        figsize=(10, 6),
                        font_size=9)

# %% [markdown]
# Tremor (TR) example:

# %%
example_trace = np.load(example_data['TR'])
data_utils.plot_trace(example_trace,
                        n_stations=8,
                        save_path=None,
                        save=False,
                        title="",
                        num=0,
                        dpi=100,
                        figsize=(10, 6),
                        font_size=9)

# %% [markdown]
# Avalanche (AV) example:

# %%
example_trace = np.load(example_data['AV'])
data_utils.plot_trace(example_trace,
                        n_stations=8,
                        save_path=None,
                        save=False,
                        title="",
                        num=0,
                        dpi=100,
                        figsize=(10, 6),
                        font_size=9)

# %% [markdown]
# Ice-Quake (IC) example:

# %%
example_trace = np.load(example_data['IC'])
data_utils.plot_trace(example_trace,
                        n_stations=8,
                        save_path=None,
                        save=False,
                        title="",
                        num=0,
                        dpi=100,
                        figsize=(10, 6),
                        font_size=9)
